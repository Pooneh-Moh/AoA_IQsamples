# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
data = pd.read_csv('info_dec.csv')

# %%
data
# Out:
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp
# 0          10.00
# 1          10.25
# 2          10.50
# 3          10.75
# 4          12.00
# ...          ...
# 9631     5144.75
# 9632     5146.00
# 9633     5146.25
# 9634     5146.50
# 9635     5146.75
#
# [9636 rows x 7 columns]

# %%
data['phi_info'].plot(subplots=True, title="Phase information of valid data points")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED38229D88>],
#       dtype=object)

# %%
data['mag_info'].plot(subplots=True, title="Magnitude information of valid data points")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED382A19C8>],
#       dtype=object)

# %% [markdown]
# # Groupping the data pased on channel
# Here I grouped the data based on it's cahnnel. Each graph represents the phase info in each channel. Yet I don't undrestand why it looks like this? Plus, I can't relate to the x grid!

# %%
grouped = data.groupby('Channel')
axes = grouped[['phi_info']].plot(title="phase_infor per channel", grid=True)
# Out:
# C:\Users\pooneh\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# C:\Users\pooneh\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:338: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %%
indexed = data.set_index(['Channel'])
indexed
# Out:
#          pkt     ant_info    phi_info    mag_info  theta_info  time_stamp
# Channel
# 23         0  (-393+170j)  -66.608140  428.192714   -0.555077       10.00
# 23         0  (-298+298j)  -45.000000  421.435642   -0.375003       10.25
# 23         0  (-137+389j)  -19.401504  412.419689   -0.161679       10.50
# 23         0    (27+409j)    3.776882  409.890229    0.031474       10.75
# 23         0   (322-255j)  128.376599  410.742011    1.069867       12.00
# ...      ...          ...         ...         ...         ...         ...
# 5         32     (43+57j)   37.030390   71.400280    0.308588     5144.75
# 5         32     (33-69j)  154.440035   76.485293    1.287109     5146.00
# 5         32     (11-77j)  171.869898   77.781746    1.432398     5146.25
# 5         32    (-14-77j) -169.695154   78.262379   -1.414270     5146.50
# 5         32    (-37-68j) -151.448608   77.414469   -1.262174     5146.75
#
# [9636 rows x 6 columns]

# %%
indexed.unstack(level=0)[['phi_info']].plot(subplots=True, title="Phase information", xlim=[0,624], ylim=[-190,+190])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CF18948>],
#       dtype=object)

# %% [markdown]
# Here is the Phase change in each channel! the phase increases to 180 and then drops down after each sample.
# The max and min is the range of change of phase.
# Here we didn't separate the antennas in each array. as a result, the data we see is: A1 A2 A3 A4, A1 A2 A3 A4, ...
# this happens 73 tims!

# %%
indexed.unstack(level=0)[['phi_info']].plot(subplots=True, title="Phase information", xlim=[0,288], ylim=[-190,+190])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CFF2988>],
#       dtype=object)

# %% [markdown]
# ## here is the Magnitude of the valid IQ samples per channel. This mag stays the say at each channel!

# %%
indexed.unstack(level=0)[['mag_info']].plot(subplots=True, title="Magnitude information", xlim=[0,288*10])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CFB8FC8>],
#       dtype=object)

# %% [markdown]
# # Now adding the frequency for each channel
# first, introducing w as center frequency of each channel!

# %%
w = []
for n in range(0,11):
    w.append(2404.25 + n*2)
print(w)
for n in range(11, 37):
    w.append(2428.25 + (n-11)*2)
print(w)
# Out:
# [2404.25, 2406.25, 2408.25, 2410.25, 2412.25, 2414.25, 2416.25, 2418.25, 2420.25, 2422.25, 2424.25]
# [2404.25, 2406.25, 2408.25, 2410.25, 2412.25, 2414.25, 2416.25, 2418.25, 2420.25, 2422.25, 2424.25, 2428.25, 2430.25, 2432.25, 2434.25, 2436.25, 2438.25, 2440.25, 2442.25, 2444.25, 2446.25, 2448.25, 2450.25, 2452.25, 2454.25, 2456.25, 2458.25, 2460.25, 2462.25, 2464.25, 2466.25, 2468.25, 2470.25, 2472.25, 2474.25, 2476.25, 2478.25]

# %%
channel = np.arange(0,37,1)
BLE_freq = pd.DataFrame({"Channel":channel, "Frequency": w})
BLE_freq['Frequency'] = BLE_freq['Frequency']*360*10**-6

# %% [markdown]
# # sampling time per channel ~ 160us
# Here I manually am changing the sampling time per channel. Because it will create extra turns along the 360 degrees if we multiply the actuall data.
# As a result, I only multiply once the time is between 10us to 160us
# ### Timing per pkt
# - 4us : guard (no sampling here)
# - 8us : the reference with 32 samples (sampling starts here)
# - 157us: sampling happens here, also the switching time is here. each 1us has 4 sampls. as a result we have 292 sampls finally. in each pkt with 4 antenna, only 288 of this data is a complete period of ant_array.

# %%
data_size = len(data)
N = int(data_size/288)
info_per_ant =[]
for n in range(N):
    for k in range(0, 288):
        data['time_per_channel'][k] = data['time_stamp'][k]
data
# Out:
# C:\Users\pooneh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp  time_per_channel
# 0          10.00             10.00
# 1          10.25             10.25
# 2          10.50             10.50
# 3          10.75             10.75
# 4          12.00             12.00
# ...          ...               ...
# 9631     5144.75            152.75
# 9632     5146.00            152.75
# 9633     5146.25            152.75
# 9634     5146.50            152.75
# 9635     5146.75            152.75
#
# [9636 rows x 8 columns]

# %%
omegat = []
for i in range(37):
    channel_posi = np.where(data['Channel'] == i)
    channel_posi_arr = np.array(channel_posi)
    if np.any(channel_posi_arr) == True:
        data['wt_per_cahnnel'] = (360*w[i]*10**-6*data['time_per_channel']) # w is in radian --> omegat in angle = omegat(rad)* 180/pi)
#         print(omegat)
data
# Out:
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp  time_per_channel  wt_per_cahnnel
# 0          10.00             10.00        8.878500
# 1          10.25             10.25        9.100462
# 2          10.50             10.50        9.322425
# 3          10.75             10.75        9.544387
# 4          12.00             12.00       10.654200
# ...          ...               ...             ...
# 9631     5144.75            152.75      135.619087
# 9632     5146.00            152.75      135.619087
# 9633     5146.25            152.75      135.619087
# 9634     5146.50            152.75      135.619087
# 9635     5146.75            152.75      135.619087
#
# [9636 rows x 9 columns]

# %% [markdown]
# # Calculating the phase with respect to the time
# For each channel, the wt (omega.t) is calculated separatly. This value is in radian. So, we concert it to degrees by: * 180/pi
# As a result, the answer will be between -180 to 180 degrees.
# Yet, if:
# real_phi = phi_info - wt_per_channel
# no furthur calculations is needed.
# - Now the angle will be between -360 to +360 degrees!
# why? because:
#     -180< phi_info<+180
#     -180 < -wt_per_channel< +180
# therefore --> -180< phi_info<+180 + -180 < -wt_per_channel< +180 --> -360 < real_phi < +360

# %%
data['real_phase'] = data['phi_info'] - data['wt_per_cahnnel']
data
# Out:
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp  time_per_channel  wt_per_cahnnel  real_phase
# 0          10.00             10.00        8.878500  -75.486640
# 1          10.25             10.25        9.100462  -54.100462
# 2          10.50             10.50        9.322425  -28.723929
# 3          10.75             10.75        9.544387   -5.767506
# 4          12.00             12.00       10.654200  117.722399
# ...          ...               ...             ...         ...
# 9631     5144.75            152.75      135.619087  -98.588698
# 9632     5146.00            152.75      135.619087   18.820947
# 9633     5146.25            152.75      135.619087   36.250810
# 9634     5146.50            152.75      135.619087 -305.314241
# 9635     5146.75            152.75      135.619087 -287.067696
#
# [9636 rows x 10 columns]

# %% [markdown]
# # Converting the angle to the [-180, 180] range:

# %%
for i in range(len(data)):
    if data['real_phase'][i] < 0:
        data['real_phase'][i] = data['real_phase'][i] + 360
data
# Out:
# C:\Users\pooneh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp  time_per_channel  wt_per_cahnnel  real_phase
# 0          10.00             10.00        8.878500  284.513360
# 1          10.25             10.25        9.100462  305.899538
# 2          10.50             10.50        9.322425  331.276071
# 3          10.75             10.75        9.544387  354.232494
# 4          12.00             12.00       10.654200  117.722399
# ...          ...               ...             ...         ...
# 9631     5144.75            152.75      135.619087  261.411302
# 9632     5146.00            152.75      135.619087   18.820947
# 9633     5146.25            152.75      135.619087   36.250810
# 9634     5146.50            152.75      135.619087   54.685759
# 9635     5146.75            152.75      135.619087   72.932304
#
# [9636 rows x 10 columns]

# %% [markdown]
# ### Now convert to [-180,180] range
# Now for phi > 180, the values should be diffrenciated by 360. As a result the total will be between [-180,180]

# %%
for i in range(len(data)):
    if data['real_phase'][i] > 180:
        data['real_phase'][i] = data['real_phase'][i] - 360
data
# Out:
# C:\Users\pooneh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       pkt  Channel     ant_info    phi_info    mag_info  theta_info  \
# 0       0       23  (-393+170j)  -66.608140  428.192714   -0.555077
# 1       0       23  (-298+298j)  -45.000000  421.435642   -0.375003
# 2       0       23  (-137+389j)  -19.401504  412.419689   -0.161679
# 3       0       23    (27+409j)    3.776882  409.890229    0.031474
# 4       0       23   (322-255j)  128.376599  410.742011    1.069867
# ...   ...      ...          ...         ...         ...         ...
# 9631   32        5     (43+57j)   37.030390   71.400280    0.308588
# 9632   32        5     (33-69j)  154.440035   76.485293    1.287109
# 9633   32        5     (11-77j)  171.869898   77.781746    1.432398
# 9634   32        5    (-14-77j) -169.695154   78.262379   -1.414270
# 9635   32        5    (-37-68j) -151.448608   77.414469   -1.262174
#
#       time_stamp  time_per_channel  wt_per_cahnnel  real_phase
# 0          10.00             10.00        8.878500  -75.486640
# 1          10.25             10.25        9.100462  -54.100462
# 2          10.50             10.50        9.322425  -28.723929
# 3          10.75             10.75        9.544387   -5.767506
# 4          12.00             12.00       10.654200  117.722399
# ...          ...               ...             ...         ...
# 9631     5144.75            152.75      135.619087  -98.588698
# 9632     5146.00            152.75      135.619087   18.820947
# 9633     5146.25            152.75      135.619087   36.250810
# 9634     5146.50            152.75      135.619087   54.685759
# 9635     5146.75            152.75      135.619087   72.932304
#
# [9636 rows x 10 columns]

# %% [markdown]
# # Plots

# %%
data.unstack(level=0)[['real_phase']].plot(subplots=True, title="Phase information", xlim=[0,288], ylim=[-190, +190])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CFEAE48>],
#       dtype=object)

# %%
data.to_csv('time_added_data.csv', index = False)

# %% [markdown]
# ## Separating each antenna per channel

# %%
data_size = len(data)
N = int(data_size/288)
info_per_ant = []
for n in range(N):
    for k in range(0 + n*288, 288*(n+1), 4):
        info_per_ant.append({"pkt": data['pkt'][k], 
                             "channel": data['Channel'][k], 
                             "phi_ant1": data['real_phase'][k + 3],
                             "phi_ant2": data['real_phase'][k], 
                             "phi_ant3": data['real_phase'][k + 1], 
                             "phi_ant4": data['real_phase'][k + 2]})
result = pd.DataFrame(info_per_ant)

# %%
result
# Out:
#       pkt  channel    phi_ant1    phi_ant2    phi_ant3    phi_ant4
# 0       0       23   -5.767506  -75.486640  -54.100462  -28.723929
# 1       0       23 -172.062353  117.722399  140.258239  165.325541
# 2       0       23   19.008260  -52.058905  -26.222297   -4.363025
# 3       0       23 -157.737556  132.984559  157.995624  179.063747
# 4       0       23   30.200423  -44.984263  -19.838345    3.173586
# ...   ...      ...         ...         ...         ...         ...
# 2371   32        5  -70.242652 -137.188442 -115.242652  -91.144722
# 2372   32        5  116.820640   45.908438   69.621442   95.389918
# 2373   32        5  -43.387913 -121.030169  -96.488688  -68.524857
# 2374   32        5  149.163639   81.588834  104.842130  128.827941
# 2375   32        5  -29.887083  -99.234736  -77.279839  -52.744104
#
# [2376 rows x 6 columns]

# %%
result.unstack(level=0)[['phi_ant1']].plot(subplots=True, title="Phase information", xlim=[0,72], ylim=[-190,+190])
result.unstack(level=0)[['phi_ant2']].plot(subplots=True, title="Phase information", xlim=[0,72], ylim=[-190,+190], color = 'red')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3CE8C888>],
#       dtype=object)

# %%
result.unstack(level=0)[['phi_ant3']].plot(subplots=True, title="Phase information", xlim=[0,72], ylim=[-190,+190], color = 'green')
result.unstack(level=0)[['phi_ant4']].plot(subplots=True, title="Phase information", xlim=[0,72], ylim=[-190,+190], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3E0EA748>],
#       dtype=object)

# %%
phi_3 = result['phi_ant3'][0:72]
phi_2 = result['phi_ant2'][0:72] 
phi_1 = result['phi_ant1'][0:72]
phi_4 = result['phi_ant4'][0:72] 
print(np.average(phi_1), np.average(phi_2), np.average(phi_3), np.average(phi_4))
# Out:
# -3.839305923630434 0.29764266760385205 -6.547826154090475 2.12052869854946

# %%
phi_channel = []
for i in range(0, len(result), 72):
    phi_channel.append({"pkt": result['pkt'][i], "channel":result['channel'][i], 
                       "ave_phi1": np.average(result['phi_ant1'][i-72:i]),
                       "ave_phi2": np.average(result['phi_ant2'][i-72:i]), 
                       "ave_phi3": np.average(result['phi_ant3'][i-72:i]),
                       "ave_phi4": np.average(result['phi_ant4'][i-72:i])})
average_phi_perchannel = pd.DataFrame(phi_channel)
average_phi_perchannel
# Out:
#     pkt  channel   ave_phi1   ave_phi2   ave_phi3   ave_phi4
# 0     0       23        NaN        NaN        NaN        NaN
# 1     0       23  -3.839306   0.297643  -6.547826   2.120529
# 2     1        4 -14.342311   4.255007   3.098080   2.013979
# 3     2       22   9.305803  -0.945476  -7.524227   0.832075
# 4     3       30   5.944282   1.239658  -5.406170  -2.251989
# 5     4       12  -2.495243   1.402188   5.111776  -1.170525
# 6     5       11  -3.900928   4.984133   3.537457   2.243784
# 7     6       29   1.928873   0.078038  -1.094381   2.993059
# 8     7       28   1.498480  -3.653065  -5.243117  -1.920773
# 9     8       10   2.964728  -2.141298  -3.781122  -0.415245
# 10    9        9   3.591457  -6.356859  -2.834938   5.147176
# 11   10       27   7.968500 -12.148784  -3.757436   4.627966
# 12   11       17  -5.810819  -5.980311  -2.582949   0.739842
# 13   12       25   7.289587   1.905151   0.330836  -1.234779
# 14   13        7  -3.231555   1.250952  -0.296924   3.162090
# 15   14        6  -5.366724   9.077469  12.441361   0.996678
# 16   15       24  -3.037076  -3.573624 -10.127206  -1.610930
# 17   16        5   8.604404  -2.030851  11.448681   9.684110
# 18   17       23   6.519217  -4.486111  -5.941274  -1.804746
# 19   18        4   8.229288  -7.054535  -3.641357   4.319996
# 20   19       22  -5.400329  -6.639044  -3.014490   0.674266
# 21   20        3   7.389656   1.689999  -0.062449   3.738368
# 22   21       21  -0.472884   3.148139   6.723595  -4.118114
# 23   22       11   9.076809  -7.461730  -3.602116  -0.089318
# 24   23       29 -12.863631   5.245955  -0.754405  -1.922452
# 25   24       10   4.145492 -11.076791 -12.689708  -4.279327
# 26   25       28  -5.650623  -5.574451  -2.177517  -8.855959
# 27   26        9   1.617521   0.501571   3.966496   2.961755
# 28   27        8   1.403029   0.941172  -5.658302  -2.021703
# 29   28       26  -1.762136  -1.822968  -8.617051 -10.177885
# 30   29       16   3.384421   7.689640   6.303582   4.878603
# 31   30        6   7.248204  -7.972712  -9.624572  -1.291911
# 32   31       24  -3.776107   5.681982   4.073305   2.666065

# %%
average_phi_perchannel.unstack(level=0)[['ave_phi1']].plot(subplots=True, title="Average Phase per Channel", xlim=[0,32], ylim=[-50,+50])
average_phi_perchannel.unstack(level=0)[['ave_phi2']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-50,+50], color = 'red')
average_phi_perchannel.unstack(level=0)[['ave_phi3']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-50,+50], color = 'green')
average_phi_perchannel.unstack(level=0)[['ave_phi4']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-50,+50], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001ED3E1C4CC8>],
#       dtype=object)

# %%
print('Ant1_phi_average',np.average(average_phi_perchannel['ave_phi1'][1:32]), 
     '\nAnt2_phi_average', np.average(average_phi_perchannel['ave_phi2'][1:32]), 
     '\nAnt3_phi_average', np.average(average_phi_perchannel['ave_phi3'][1:32]),
     '\nAnt4_phi_average', np.average(average_phi_perchannel['ave_phi4'][1:32]))
# Out:
# Ant1_phi_average 0.9656833666736894
# Ant2_phi_average -1.4584481955292405
# Ant3_phi_average -1.6779894626036291
# Ant4_phi_average 0.25705214914902214
