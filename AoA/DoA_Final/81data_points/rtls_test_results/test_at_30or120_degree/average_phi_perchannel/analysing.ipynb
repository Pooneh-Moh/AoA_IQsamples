# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %%
average_phi_perchannel_1 = pd.read_csv('average_phi_perchannel_1.csv')
average_phi_perchannel_2 = pd.read_csv('average_phi_perchannel_2.csv')
average_phi_perchannel_3 = pd.read_csv('average_phi_perchannel_3.csv')
average_phi_perchannel_4 = pd.read_csv('average_phi_perchannel_4.csv')

# %%
average_phi_perchannel_1.unstack(level=0)[['ave_phi1']].plot(subplots=True, title="Average Phase per Channel", xlim=[0,32], ylim=[-180,+180])
average_phi_perchannel_1.unstack(level=0)[['ave_phi2']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'red')
average_phi_perchannel_1.unstack(level=0)[['ave_phi3']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'green')
average_phi_perchannel_1.unstack(level=0)[['ave_phi4']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCA61DFA08>],
#       dtype=object)

# %%
average_phi_perchannel_2.unstack(level=0)[['ave_phi1']].plot(subplots=True, title="Average Phase per Channel", xlim=[0,32], ylim=[-180,+180])
average_phi_perchannel_2.unstack(level=0)[['ave_phi2']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'red')
average_phi_perchannel_2.unstack(level=0)[['ave_phi3']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'green')
average_phi_perchannel_2.unstack(level=0)[['ave_phi4']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCA6650FC8>],
#       dtype=object)

# %%
average_phi_perchannel_3.unstack(level=0)[['ave_phi1']].plot(subplots=True, title="Average Phase per Channel", xlim=[0,32], ylim=[-180,+180])
average_phi_perchannel_3.unstack(level=0)[['ave_phi2']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'red')
average_phi_perchannel_3.unstack(level=0)[['ave_phi3']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'green')
average_phi_perchannel_3.unstack(level=0)[['ave_phi4']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCA66E6788>],
#       dtype=object)

# %%
average_phi_perchannel_4.unstack(level=0)[['ave_phi1']].plot(subplots=True, title="Average Phase per Channel", xlim=[0,32], ylim=[-180,+180])
average_phi_perchannel_4.unstack(level=0)[['ave_phi2']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'red')
average_phi_perchannel_4.unstack(level=0)[['ave_phi3']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'green')
average_phi_perchannel_4.unstack(level=0)[['ave_phi4']].plot(subplots=True, title="Average Phase per Channe", xlim=[0,32], ylim=[-180,+180], color = 'yellow')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CCA6762608>],
#       dtype=object)

# %%
average_phi_perchannel_1
# Out:
#     pkt  channel   ave_phi1   ave_phi2   ave_phi3   ave_phi4
# 0     0       11  -6.908518   3.865181  11.852136   5.049125
# 1     1        4 -43.695072  23.709806   1.479620 -20.855011
# 2     2       34  46.475467 -60.353613 -13.152449  34.183155
# 3     3       27  13.500504   5.185587  22.835497  30.576700
# 4     4       20   2.431383  -0.861747  -3.110029  -0.482145
# 5     5       28 -38.316861  28.659354   6.331967 -15.940772
# 6     6       21   6.994699   0.358496   2.497031  -0.101439
# 7     7       29  -5.992363  16.216393   9.009291  -8.533450
# 8     8       22  28.799920  -2.734312   4.579731  31.958875
# 9     9       15 -38.108567  29.790223   7.407794 -15.610070
# 10   10        8  18.380940  -4.365421  38.249317  40.784157
# 11   11        1  15.941212 -13.129719 -19.874772  13.093541
# 12   12        9 -12.524906   8.621475 -13.034317 -30.032806
# 13   13       25 -14.303614 -12.220121 -24.297231 -46.766662
# ...
