# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import math

def cal_magnitude(q_value,i_value):
    return math.sqrt(math.pow(q_value,2)+math.pow(i_value,2))

# %%
#C:\ti\simplelink_cc13x2_26x2_sdk_4_40_04_04\tools\ble5stack\rtls_agent\examples\3ANT\ofoghi\rtls_aoa_iq_with_rtls_util_export_into_csv_3ant_AoA_log\04_16_2021_16_55_55_rtls_raw_iq_samples_0x11_zero_f88a5e2d7808_0.csv
path = 'C:/ti/simplelink_cc13x2_26x2_sdk_4_40_04_04/tools/ble5stack/rtls_agent/examples/3ANT/ofoghi/rtls_aoa_iq_with_rtls_util_export_into_csv_3ant_AoA_log/04_13_2021_11_19_29_rtls_raw_iq_samples_0x11_f88a5e2d7808_0.csv'
new_data = pd.read_csv(path)
angle_res = []
angle_per_anetnna =[]
time_stamp = []
info =[]
info_per_ant =[]
channel = []
data_size = len(new_data)
N = int(data_size/624)
print('Number of pakts are', N, int(N/2))
t = np.arange(0, 157*N, 0.25)
for n in range(N):
    for i in range(36+n*624, 624*(n+1), 8):
        for j in range(i, i+4):
            info.append({"pkt": n, "Channel": new_data['channel'][j], "ant_info": complex(new_data['i'][j], new_data['q'][j]),
                         "I": new_data['i'][j],
                         "Q":new_data['q'][j],
                         "Magnitude": cal_magnitude(new_data['q'][j], new_data['i'][j]),
                         "time_stamp": t[j], "sample_idx":new_data['sample_idx'][j]})
    info_dec = pd.DataFrame(info)
#     info_dec.to_csv('IQ_info.csv', index=False)
print('Finished each cahnnel has 296 data points')
# Out:
# Number of pakts are 74 37
# Finished each cahnnel has 296 data points

# %%
print(len(info_dec)- 70*(624-36)/2)
# Out:
# 1324.0

# %%
info_dec[len(info_dec)-286:len(info_dec)]
# Out:
#        pkt  Channel     ant_info    I    Q   Magnitude  time_stamp  sample_idx
# 21618   73       15 -101.0+34.0j -101   34  106.569226    11401.50          54
# 21619   73       15  -76.0+72.0j  -76   72  104.690019    11401.75          55
# 21620   73       15  102.0+25.0j  102   25  105.019046    11403.00          60
# 21621   73       15  105.0-19.0j  105  -19  106.705201    11403.25          61
# 21622   73       15   86.0-58.0j   86  -58  103.730420    11403.50          62
# ...    ...      ...          ...  ...  ...         ...         ...         ...
# 21899   73       15 -17.0-139.0j  -17 -139  140.035710    11541.75         615
# 21900   73       15 -117.0+67.0j -117   67  134.825814    11543.00         620
# 21901   73       15 -84.0+101.0j  -84  101  131.365901    11543.25         621
# 21902   73       15 -34.0+125.0j  -34  125  129.541499    11543.50         622
# 21903   73       15  15.0+131.0j   15  131  131.855982    11543.75         623
#
# [286 rows x 8 columns]

# %%
info_dec['time_per_channel'] =  info_dec['time_stamp']
for i in range(0, len(info_dec)- 296, 296):
    info_dec['time_per_channel'][i+296:i+2*296] = info_dec['time_stamp'][0:296]
# Out:
# <ipython-input-6-3714dc7095be>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   info_dec['time_per_channel'][i+296:i+2*296] = info_dec['time_stamp'][0:296]

# %%
info_dec[286:299]
# Out:
#      pkt  Channel     ant_info    I   Q   Magnitude  time_stamp  sample_idx  \
# 286    0       33   99.0+24.0j   99  24  101.867561      151.50         606
# 287    0       33  101.0-13.0j  101 -13  101.833197      151.75         607
# 288    0       33   32.0-97.0j   32 -97  102.142058      153.00         612
# 289    0       33 -7.0-096.00j   -7 -96   96.254870      153.25         613
# 290    0       33  -43.0-85.0j  -43 -85   95.257546      153.50         614
# 291    0       33  -78.0-57.0j  -78 -57   96.607453      153.75         615
# 292    0       33 -2.0+099.00j   -2  99   99.020200      155.00         620
# 293    0       33   34.0+92.0j   34  92   98.081599      155.25         621
# 294    0       33   69.0+69.0j   69  69   97.580736      155.50         622
# 295    0       33   91.0+39.0j   91  39   99.005050      155.75         623
# 296    1       31   24.0-76.0j   24 -76   79.699435      165.00          36
# 297    1       31  -12.0-79.0j  -12 -79   79.906195      165.25          37
# 298    1       31  -45.0-69.0j  -45 -69   82.377181      165.50          38
#
#      time_per_channel
# 286            151.50
# 287            151.75
# 288            153.00
# 289            153.25
# 290            153.50
# 291            153.75
# 292            155.00
# 293            155.25
# 294            155.50
# 295            155.75
# 296              9.00
# 297              9.25
# 298              9.50

# %%
df = info_dec.drop(info_dec[info_dec.time_per_channel > 151.75].index)
len(df)
# Out:
# 21312

# %%
N = int(len(df)/288)

# %%
lst_ant1 = []
lst_ant2 = []
lst_ant3 = []


for i in range(0, len(df), 12):    
    lst_ant2.append(df[i:i+4])
    lst_ant1.append(df[i+4:i+8])
    lst_ant3.append(df[i+8:i+12])

# %%
df_ant1 = pd.concat(lst_ant1)
df_ant2 = pd.concat(lst_ant2)
df_ant3 = pd.concat(lst_ant3)

# %%
df_ant1.to_csv('df_ant1_30.csv', index=True)
df_ant2.to_csv('df_ant2_30.csv', index=True)
df_ant3.to_csv('df_ant3_30.csv', index=True)
